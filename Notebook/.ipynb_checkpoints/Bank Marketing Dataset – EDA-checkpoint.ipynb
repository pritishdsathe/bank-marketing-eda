# %% [markdown]
# # 📊 Bank Marketing Dataset – Exploratory Data Analysis (EDA) Report
# ## 📁 Dataset Summary
# ## Source: UCI Machine Learning Repository
#
# ## Context: Predict whether a customer subscribes to a term deposit based on past campaign data.
#
# ### Total Records: ~4521+
#
# ### Total Features: 17
#
# ### Target Variable: y – whether the customer subscribed (yes/no)
#
# ## 🎯 Objective
# This notebook explores the **Bank Marketing Dataset** to understand customer behavior and identify patterns that influence whether a client subscribes to a **term deposit**. Through visual and statistical analysis, we aim to extract insights that can guide marketing strategies.
#
# The dataset contains client information along with campaign interaction details and the final outcome (`y`: whether the client subscribed).
#
# Let’s dive into the data!

# %%
# Necessary imports.

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## 📥 Step 1: Loading the Dataset

# We start by loading the dataset using `pandas`. Let’s take a quick look at the first few rows to understand its structure.

bank_record = pd.read_csv("bank.csv", sep=";")
bank_record
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
## 🧾 Step 2: Initial Data Overview

'''
Let’s get a feel for the dataset structure: 
number of rows and columns, 
column names, data types, 
and basic statistical descriptions of the features.

'''

bank_record.describe(include="all")
# Out:
#                 age         job  marital  education default       balance  \
# count   4521.000000        4521     4521       4521    4521   4521.000000
# unique          NaN          12        3          4       2           NaN
# top             NaN  management  married  secondary      no           NaN
# freq            NaN         969     2797       2306    4445           NaN
# mean      41.170095         NaN      NaN        NaN     NaN   1422.657819
# std       10.576211         NaN      NaN        NaN     NaN   3009.638142
# min       19.000000         NaN      NaN        NaN     NaN  -3313.000000
# 25%       33.000000         NaN      NaN        NaN     NaN     69.000000
# 50%       39.000000         NaN      NaN        NaN     NaN    444.000000
# 75%       49.000000         NaN      NaN        NaN     NaN   1480.000000
# max       87.000000         NaN      NaN        NaN     NaN  71188.000000
#
#        housing  loan   contact          day month     duration     campaign  \
# ...

# %%
bank_record.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# # 🗂️ Summary of Campaign Outreach Attempts
#
# * The campaign column in the dataset records how many times a customer was contacted during the most recent marketing campaign. This helps us understand the persistence and outreach strategy used by the bank.
#
# # 📋 Unique Campaign Values and Distribution
# * The dataset contains 32 unique values in the campaign column.
# * These values range from 1 to 50, showing wide variability in how many contact attempts were made.
#
#
# | Campaign | Frequency |
# | -------- | --------- |
# | 1        | 1734      |
# | 2        | 1264      |
# | 3        | 558       |
# | 4        | 325       |
# | 5        | 167       |
# | 6        | 155       |
# | 7        | 75        |
# | 8        | 56        |
# | 9        | 30        |
# | 10       | 27        |
# | 11       | 22        |
# | 12       | 21        |
# | 13       | 17        |
# | 14       | 10        |
# | 15       | 9         |
# | 16       | 8         |
# | 17       | 7         |
# | 18       | 7         |
# | 19       | 3         |
# | 20       | 3         |
# | 21       | 2         |
# | 22       | 2         |
# | 23       | 2         |
# | 24       | 3         |
# | 25       | 4         |
# | 28       | 3         |
# | 29       | 1         |
# | 30       | 1         |
# | 31       | 1         |
# | 32       | 2         |
# | 44       | 1         |
# | 50       | 1         |

# %%
#Unique value count from the campaign column
bank_record['campaign'].unique()
# Out:
# array([ 1,  4,  2,  5,  3,  6, 18, 10,  9,  7, 12, 14, 13, 24, 11,  8, 29,
#        32, 16, 22, 15, 30, 25, 21, 17, 19, 23, 20, 50, 28, 31, 44],
#       dtype=int64)

# %%
len(bank_record['campaign'].unique())
# Out:
# 32

# %%
campaign_count = bank_record.groupby(['campaign']).size()

# %%
campaign_count
# Out:
# campaign
# 1     1734
# 2     1264
# 3      558
# 4      325
# 5      167
# 6      155
# 7       75
# 8       56
# 9       30
# 10      27
# 11      22
# 12      21
# 13      17
# 14      10
# 15       9
# 16       8
# 17       7
# 18       7
# 19       3
# 20       3
# 21       2
# 22       2
# 23       2
# 24       3
# 25       4
# 28       3
# 29       1
# 30       1
# 31       1
# 32       2
# 44       1
# 50       1
# dtype: int64

# %% [markdown]
# ---
#
# | Campaign | Frequency |
# | -------- | --------- |
# | 1        | 1734      |
# | 2        | 1264      |
# | 3        | 558       |
# | 4        | 325       |
# | 5        | 167       |
#
# **✅ These top 5 campaign counts represent the majority of cases, suggesting most clients were contacted between 1 and 5 times during the campaign.**
#
# 📊 Visualization
# * A bar plot was created to show the distribution of campaign counts.
#
# * The plot highlights a sharp drop-off in frequency after campaign count 5.
#
# * This indicates the majority of clients were contacted a few times, while repeated attempts (above 10) were rare.

# %%
top_counts = campaign_count.sort_values(ascending=False).head(5)

# %%
top_counts
# Out:
# campaign
# 1    1734
# 2    1264
# 3     558
# 4     325
# 5     167
# dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=top_counts.index.astype(str), y=top_counts.values, color='steelblue')
plt.xlabel("Campaign Number")
plt.ylabel("Number of clients contacted")
plt.title("Top 5 campaigns by number of clients contacted")
plt.grid(False)
plt.savefig('Plots/top_5_campaigns.png')
plt.show()

# %% [markdown]
# # 💡 Insights
#
#
# 1. 🔁 Short Campaigns Dominate: Most clients were contacted only once or twice — over 60% of cases fall within campaign = 1 or 2.
#
# 2. ⚠️ Diminishing Returns?: Higher campaign values (e.g. >10) occur rarely, and might indicate lower efficiency or client fatigue.
#
# 3. 🎯 Focus Area for Modeling: This column can help assess whether more contact attempts lead to better conversion, or if fewer, targeted efforts are more successful.
#
# # 🧭 Conclusion
#
# * The campaign column is skewed toward lower values, showing that minimal contact is the common strategy.
#
# * This variable could play a critical role in understanding client responsiveness and improving future marketing strategies.

# %% [markdown]
# ---

# %% [markdown]
# ## 🏦 Overall Summary: 🧾 EDA on Loan Status and Subscription Behavior
#
#  - Understanding customer loan profiles gives deep insight into financial status and their likelihood of subscribing to bank services.
#
# ## 🔍 Loan Combinations: Client Distribution
# Explored the overlap between housing loan and personal loan status in relation to term deposit subscription.
#
# | Loan Status                     | Count |
# | ------------------------------- | ----- |
# | ✅ No Housing & No Personal Loan | 1,677 |
# | 🏠 Housing Loan Only            | 2,153 |
# | 💳 Personal Loan Only           | 258   |
# | 🏠 + 💳 Both Loans              | 406   |
#
# **Total evaluated: 4,494 clients**
#
#
# # 📊 Subscription Rate by Loan Group
#
# ## A countplot visualized the number of subscriptions (y = yes) across different loan categories:
#
# * ✅ No Loans group shows the highest number of subscriptions.
#
# * 🏠 and 💳 Loan Holders, especially those with both loans, show noticeably fewer subscriptions.
#
# ---
#
# | Loan Status        | % of Subscribers |
# | ------------------ | ---------------- |
# | ✅ No Loans         | **54.3%**        |
# | 🏠 Housing Only    | 37.4%            |
# | 💳 Personal Only   | 3.5%             |
# | 🏠 + 💳 Both Loans | 4.8%             |
#
# **Presented via a pie chart to show the subscriber composition by loan group.**
#
# ---
#
# | Loan Group         | No (Ratio) | Yes (Ratio) |
# | ------------------ | ---------- | ----------- |
# | ✅ No Loans         | 0.831      | 0.169       |
# | 🏠 + 💳 Both Loans | 0.938      | 0.062       |
#
# # A bar chart compared the subscription ratios between these two groups:
#
# * Clients with no loans are nearly 3× more likely to subscribe than those with both housing and personal loans.
#
# * A clear negative correlation appears between total loan burden and deposit subscription.

# %%
len(bank_record[(bank_record['housing'] == 'yes') & (bank_record['loan'] == 'yes')])
# Out:
# 406

# %%
len(bank_record[(bank_record['housing'] == 'no') & (bank_record['loan'] == 'no')])
# Out:
# 1677

# %%
len(bank_record[(bank_record['housing'] == 'no') & (bank_record['loan'] == 'yes')])
# Out:
# 285

# %%
len(bank_record[(bank_record['housing'] == 'yes') & (bank_record['loan'] == 'no')])
# Out:
# 2153

# %%
bank_record["Loan Type"]
bank_record.loc[(bank_record['housing'] == 'yes') & (bank_record['loan'] == 'no'), 'Loan Type'] = 'Housing Loan Only'
bank_record.loc[(bank_record['housing'] == 'no') & (bank_record['loan'] == 'yes'), 'Loan Type'] = "Personal Loan Only"
bank_record.loc[(bank_record['housing'] == 'yes') & (bank_record['loan'] == 'yes'), 'Loan Type'] = 'Both Loans'
bank_record.loc[(bank_record['housing'] == 'no') & (bank_record['loan'] == 'no'), 'Loan Type'] = 'No Loans'


plt.figure(figsize=(10,6))
sns.countplot(data=bank_record, x='Loan Type', hue='y', palette='viridis')
plt.title("Subscription status by loan group")
plt.tight_layout()
plt.savefig('Plots/Subscription_status_by_loan_group')
plt.show()

# %%
# Filtered only those who subscribed
subscribed = bank_record[bank_record['y'] == 'yes']

# Count of each loan type among subscribers
loan_counts = subscribed['Loan Type'].value_counts()

# Plot
plt.figure(figsize=(10,6))
plt.pie(loan_counts, labels=loan_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightgreen', 'orange', 'pink'])
plt.title("Subscription Distribution by Loan Type")
plt.axis('equal')  # Circle shape
plt.savefig('plots/subscription_pie_by_loan_type.png')
plt.show()

# %%
subset = bank_record[(bank_record['housing'] == 'no') & (bank_record['loan'] == 'no')].copy()
subset['y'].value_counts(normalize=True)
# Out:
# y
# no     0.831246
# yes    0.168754
# Name: proportion, dtype: float64

# %%
subset2 = bank_record[(bank_record['housing'] == 'yes') & (bank_record['loan'] == 'yes')].copy()
subset2['y'].value_counts(normalize=True)  # Subscription rate in this group
# Out:
# y
# no     0.938424
# yes    0.061576
# Name: proportion, dtype: float64

# %%
# Compare subscription rate
group_all_loans = subset2['y'].value_counts(normalize=True)
group_no_loans = subset['y'].value_counts(normalize=True)

# %%
group_all_loans
# Out:
# y
# no     0.938424
# yes    0.061576
# Name: proportion, dtype: float64

# %%
group_no_loans
# Out:
# y
# no     0.831246
# yes    0.168754
# Name: proportion, dtype: float64

# %%
subs_rate = pd.DataFrame({'Both Loans': group_all_loans, 'No Loans': group_no_loans}).T
subs_rate.plot(kind='bar', stacked=False)
plt.ylim(0,1)
plt.title("Subscription Rate Comparision")
plt.ylabel("Proportion")
plt.savefig('Plots/Subscription Rate Comparision.png')
plt.show()

# %% [markdown]
# # 💡 Insights
#
# **✅ No Loans = Higher Subscription Ratio**
# The group without loans shows the highest ratio of yes responses **(16.9%)**, indicating stronger interest or financial ability to commit.
#
# 🏠 + 💳 Both Loans = Lowest Conversion
# Clients holding both loans have the lowest subscription ratio **(6.2%)**, suggesting financial obligations may deter further commitments.
#
# 🧮 Skewed Subscription Distribution
# Over **54%** of all subscribers had **no loans**. Clients with **only housing loans** contributed **37.4%**, while those with any **personal loan (alone or with housing) made up just 8.3% combined.**

# %% [markdown]
# ---

# %% [markdown]
# # 👵 EDA on Clients Aged Above 60 and Retired
#
# **📋 Group Definition**
# - Filtered clients who are:
#
# * Above 60 years of age
#
# * Job = "retired"
#
# **Total count: 93 clients**
#
# **💰 Bank Balance Distribution**
#
# * A histogram was used to display the distribution of balance among this segment.
#
# * The distribution appeared right-skewed, indicating a few individuals hold substantially higher balances.
#
# | Status             | Percentage |
# | ------------------ | ---------- |
# | ❌ No Housing Loan  | **92.5%**  |
# | ✅ Has Housing Loan | **7.5%**   |
#
# * Visualized using a pie chart.
#
# * Majority of this group do not have housing loans.
#
# | Status              | Percentage |
# | ------------------- | ---------- |
# | ❌ No Personal Loan  | **98.9%**  |
# | ✅ Has Personal Loan | **1.1%**   |
#
# * Very few clients in this group have a personal loan.
#
# | Subscribed (`y`) | Count |
# | ---------------- | ----- |
# | ✅ Yes            | 36    |
# | ❌ No             | 57    |
#
# * Visualized with a countplot.
#
# * **38.7%** of retired clients above 60 subscribed, which is **notably high** compared to the general population.
#
# 📦 Age Spread in Group
# - Displayed using a boxplot.
#
# * Minimum age: 61
#
# * Median age: 71
#
# * Maximum age: 87
#
# *The boxplot shows the age distribution within the group is centered around the early 70s, with a spread from early 60s to late 80s.*

# %%
retired_seniors = bank_record[(bank_record['age'] > 60) & (bank_record['job'] == 'retired')]
retired_seniors
# Out:
#       age      job   marital  education default  balance housing loan  \
# 27     67  retired   married    unknown      no      696      no   no
# 30     68  retired  divorced  secondary      no     4189      no   no
# 36     78  retired  divorced    primary      no      229      no   no
# 61     63  retired   married  secondary      no      415     yes   no
# 129    77  retired  divorced   tertiary      no     4659      no   no
# ...   ...      ...       ...        ...     ...      ...     ...  ...
# 4323   83  retired  divorced    primary      no        0      no   no
# 4337   73  retired   married    unknown      no      519      no   no
# 4364   63  retired  divorced  secondary      no     1490      no   no
# 4388   83  retired  divorced    primary      no     1097      no   no
# 4413   65  retired   married    primary      no      493      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y  \
# ...

# %%
sns.histplot(retired_seniors['balance'], kde=True)
plt.title('Balance Distribution of Retired People')
plt.grid(False)
plt.xlabel("Balance Amount")
plt.ylabel("Number of People")
plt.xlim(-100, 25000)
plt.savefig('Plots/Balance_Distribution_Among_Retired_People.png')
plt.show()

# %%
housing_ratio = retired_seniors['housing'].value_counts(normalize=True)
plt.figure(figsize=(12, 6))
plt.pie(housing_ratio.values, labels=housing_ratio.index, autopct='%1.1f%%', startangle=90)
plt.title("Housing Loan Status Among Retired People")
plt.axis('equal')  # Equal aspect ratio to make pie circular
plt.savefig('Plots/Housing_loan_status_retired.png')
plt.show()

# %%
personal_loan_ratio = retired_seniors['loan'].value_counts(normalize=True)
plt.figure(figsize=(12, 6))
plt.pie(personal_loan_ratio.values, labels=personal_loan_ratio.index, autopct='%1.1f%%', startangle=90)
plt.title("Personal Loan Status Among Retired People")
plt.axis('equal')  # Equal aspect ratio to make pie circular
plt.savefig('Plots/Personal_loan_status_retired.png')
plt.show()

# %%
sns.countplot(data=retired_seniors, x='y')
plt.title("Subscription Status of Retired People.")
plt.xlabel("Subscription Status")
plt.ylabel("Count of people")
plt.savefig('Plots/Number_of_retired_subscribers.png')
plt.show()

# %%
retired_seniors['y'].value_counts()
# Out:
# y
# no     57
# yes    36
# Name: count, dtype: int64

# %%
retired_seniors['age'].describe()
# Out:
# count    93.000000
# mean     71.333333
# std       6.671375
# min      61.000000
# 25%      66.000000
# 50%      71.000000
# 75%      77.000000
# max      87.000000
# Name: age, dtype: float64

# %%
sns.boxplot(data=retired_seniors, y='age')
plt.title('Age Spread of Retired People >60')
plt.xlabel("Retired People")
plt.ylabel("Age")
plt.title("Age Spread of Retired Seniors")
plt.savefig("Plots/Age_Spread_Retired_People.png")
plt.show()

# %% [markdown]
# # 💡 Insights
# 1. 👵 Small but Valuable Segment
# Only 93 clients fall into this retired & 60+ category, but they show a stronger-than-average subscription rate.
#
# 2. 💰 Low Debt Load
# A very small percentage hold any form of loan (7.5% housing, 1.1% personal), suggesting they are debt-free or financially stable.
#
# 3. ✅ High Balance Variance
# The histogram indicates some clients have significantly higher balances, making them strong prospects for term deposit marketing.
#
# 4. 📉 High Conversion Rate
# Despite being a small group, 36 out of 93 subscribed—a conversion rate of ~39%, much higher than overall dataset trends.
#
# # 🏁 Conclusion
# * Retired clients over 60 represent a low-risk, high-potential group for term deposit products.
#
# * With low loan exposure and relatively high subscription rates, they are ideal candidates for future campaigns.
#
# * Tailored marketing toward this segment could yield strong returns, especially leveraging messaging around financial security and retirement planning.
#
# ----

# %% [markdown]
# # 📅 EDA on Contact Month and Subscription Behavior
#
# ## 📊 Monthly Contact Volume
#
# | Month  | Contact Count |
# | ------ | ------------- |
# | ⚪ Jan  | 148           |
# | 🟤 Feb | 222           |
# | 💜 Mar | 49            |
# | 🔴 Apr | 293           |
# | 🟢 May | 1,398         |
# | 🟣 Jun | 531           |
# | 🔵 Jul | 706           |
# | 🟡 Aug | 633           |
# | 🧊 Sep | 52            |
# | 🧡 Oct | 80            |
# | 🟠 Nov | 389           |
# | ⚫ Dec  | 20            |
#
# # 🧾 Subscription Status by Month
#
# | Month | Subscribed (`yes`) | Not Subscribed (`no`) |
# | ----- | ------------------ | --------------------- |
# | Jan   | 16                 | 132                   |
# | Feb   | 38                 | 184                   |
# | Mar   | 21                 | 28                    |
# | Apr   | 56                 | 237                   |
# | May   | 93                 | 1305                  |
# | Jun   | 55                 | 476                   |
# | Jul   | 61                 | 645                   |
# | Aug   | 79                 | 554                   |
# | Sep   | 17                 | 35                    |
# | Oct   | 37                 | 43                    |
# | Nov   | 39                 | 350                   |
# | Dec   | 9                  | 11                    |
#
# # 📈 Subscription Rate per Month (%)
#
# | Month | Subscription Rate (%) |
# | ----- | --------------------- |
# | Jan   | 10.81%                |
# | Feb   | 17.12%                |
# | Mar   | 42.86%                |
# | Apr   | 19.11%                |
# | May   | **6.65%**             |
# | Jun   | 10.36%                |
# | Jul   | 8.64%                 |
# | Aug   | 12.48%                |
# | Sep   | 32.69%                |
# | Oct   | **46.25%**            |
# | Nov   | 10.03%                |
# | Dec   | 45.00%                |
#
# * Displayed using a line chart to show monthly trends in subscription effectiveness.
#
# * **October**, **December**, and **March** lead in subscription rates despite low outreach.

# %%
bank_record.groupby('month').size().sort_values(ascending=False)
# Out:
# month
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# dtype: int64

# %%
bank_record.groupby(['month', 'y']).size().sort_values(ascending=False).reset_index(name='Count of People')
# Out:
#    month    y  Count of People
# 0    may   no             1305
# 1    jul   no              645
# 2    aug   no              554
# 3    jun   no              476
# 4    nov   no              350
# 5    apr   no              237
# 6    feb   no              184
# 7    jan   no              132
# 8    may  yes               93
# 9    aug  yes               79
# 10   jul  yes               61
# 11   apr  yes               56
# 12   jun  yes               55
# 13   oct   no               43
# 14   nov  yes               39
# 15   feb  yes               38
# 16   oct  yes               37
# 17   sep   no               35
# 18   mar   no               28
# 19   mar  yes               21
# 20   sep  yes               17
# 21   jan  yes               16
# 22   dec   no               11
# 23   dec  yes                9

# %%
subscription_rate_per_month = bank_record.groupby('month')['y'].value_counts(normalize=True).unstack()['yes'] * 100
subscription_rate_per_month = subscription_rate_per_month.reset_index(name='Subscription Rate (%)')

# %%
subscription_rate_per_month.sort_values(by='Subscription Rate (%)', ascending=False)
# Out:
#    month  Subscription Rate (%)
# 10   oct              46.250000
# 2    dec              45.000000
# 7    mar              42.857143
# 11   sep              32.692308
# 0    apr              19.112628
# 3    feb              17.117117
# 1    aug              12.480253
# 4    jan              10.810811
# 6    jun              10.357815
# 9    nov              10.025707
# 5    jul               8.640227
# 8    may               6.652361

# %%
plt.figure(figsize=(10,4))
plt.plot(subscription_rate_per_month['month'], subscription_rate_per_month['Subscription Rate (%)'], marker='o', linestyle='-', color='red')
plt.title("Monthly Subscription Rate")
plt.xlabel("Months")
plt.ylabel("Subscription Rate (%)")
plt.tight_layout()
plt.savefig('Plots/Monthly_Subscription_Rate.png')
plt.show()

# %% [markdown]
# # 💡 Insights
# 1. 📉 High Contact ≠ High Conversion
# **May**, with the highest outreach, has the lowest success rate.
#
# 2. 🚀 High-Yield, Low-Volume Months
# **Oct**, **Dec**, and **Mar** show top conversion rates with minimal contacts.
#
# 3. 🧠 Timing Is Critical
# Performance varies significantly by month — strategy should be aligned with **high-conversion windows**, not just volume.
#
# 4. 🛠️ Refinement Opportunity
# Low-performing high-volume months could be **re-evaluated** for messaging, timing, or client segmentation.
#
#
# # 🏁 Conclusion
#
# * The **month of contact** plays a major role in subscription outcome.
#
# * Focusing on **high-conversion months** while improving the effectiveness of campaigns in low-yield periods can significantly enhance overall results.
#
# * A **data-driven calendar-based strategy** could improve conversion rates with **less effort and better targeting.**
#
# ----

# %% [markdown]
# # 📞 EDA on Contact Method and Lead Generation
#
# # 📊 Contact Method Usage
#
# | Contact Method | Number of Contacts |
# | -------------- | ------------------ |
# | 📱 Cellular    | 2,896              |
# | ❓ Unknown      | 1,324              |
# | ☎️ Telephone   | 301                |
#
# * Majority of contacts were made via cellular.
#
# * A significant portion of contacts have unknown method.
#
# * Telephone contacts are the least frequent.
#
# # 🎯 Lead Generation by Contact Method
#
# | Contact Method | Leads Generated |
# | -------------- | --------------- |
# | 📱 Cellular    | 416             |
# | ❓ Unknown      | 61              |
# | ☎️ Telephone   | 44              |
#
# * Cellular contacts generated the highest number of leads.
#
# * Both unknown and telephone methods produced considerably fewer leads.
#
# # 📈 Visualization
# * Data visualized using a bar plot, clearly showing cellular as the dominant and most effective contact method for lead generation.

# %%
bank_record['contact'].value_counts()
# Out:
# contact
# cellular     2896
# unknown      1324
# telephone     301
# Name: count, dtype: int64

# %%
highest_lead_generation = bank_record[bank_record['y'] == 'yes']['contact'].value_counts()

# %%
highest_lead_generation_df = highest_lead_generation.reset_index()
highest_lead_generation_df.columns = ['contact_type', 'lead_count']  # rename columns

# %%
highest_lead_generation_df
# Out:
#   contact_type  lead_count
# 0     cellular         416
# 1      unknown          61
# 2    telephone          44

# %%
plt.figure(figsize=(10,4))
sns.barplot(data=highest_lead_generation_df, x='contact_type', y='lead_count', color='skyblue')
plt.title("Lead Generation by Contact Type")
plt.grid(False)
plt.xlabel("Type of Contact")
plt.ylabel("Total Lead Count")
plt.tight_layout()
plt.savefig('Plots/Lead_Generation_By_Contact_Type.png')
plt.show()

# %% [markdown]
# ### 💡 Insights
# 1. 📱 Cellular is the Primary and Most Effective Contact Method
# Most customer interactions happen over cellular, which also yields the highest number of leads.
#
# 2. ❓ Unknown Contact Method Needs Review
# A large number of contacts are labeled unknown, indicating data quality issues or missing metadata that could be improved.
#
# 3. ☎️ Telephone Has Limited Reach and Impact
# Telephone contacts are both low in volume and less effective in lead generation, suggesting possible deprioritization or reconsideration.
#
# ### Conclusion
# * Prioritize cellular channels for outreach campaigns to maximize lead generation.
#
# * Investigate and reduce unknown contact types for better data clarity.
#
# * Reassess the use of telephone contact to optimize resource allocation.
#
# ---

# %% [markdown]
# ## 💼 EDA on Job Role: Focus on Entrepreneurs
#
# ### 🧑‍💻 Job Distribution Overview
# - 👔 Management: 969
# - 🛠️ Blue-collar: 946
# - 🖥️ Technician: 768
# - 🗃️ Admin.: 478
# - 🧑‍🍳 Services: 417
# - 👵 Retired: 230
# - 🧑‍🔧 Self-employed: 183
# - 📈 Entrepreneur: 168
# - 💼 Unemployed: 128
# - 🧹 Housemaid: 112
# - 🎓 Student: 84
# - ❓ Unknown: 38
#
# ---
#
# ### 📌 Focus: Entrepreneurs
# - **Total:** 168
#
# #### 📊 Subscription Status
# - ✅ Subscribed: 15
# - ❌ Not Subscribed: 153
#
# #### 📎 Subscription Rate (Pie Chart)
# - ❌ No: 91.07%
# - ✅ Yes: 8.93%
#
# ---
#
# ### 🏦 Loan Distribution (Among Entrepreneurs)
# - 🏠 Housing Loan Only: 65
# - ✅ No Loans: 62
# - 🏠💳 Both Loans: 29
# - 💳 Personal Loan Only: 12

# %%
bank_record['job'].value_counts()
# Out:
# job
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: count, dtype: int64

# %%
bank_record[bank_record['job'] == 'entrepreneur']
# Out:
#       age           job   marital  education default  balance housing loan  \
# 8      41  entrepreneur   married   tertiary      no      221     yes   no
# 23     44  entrepreneur   married  secondary      no       93      no   no
# 48     32  entrepreneur    single    primary     yes     -849     yes  yes
# 71     42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 150    41  entrepreneur   married    unknown      no       89     yes   no
# ...   ...           ...       ...        ...     ...      ...     ...  ...
# 4401   38  entrepreneur  divorced   tertiary      no     7929      no   no
# 4402   41  entrepreneur   married    primary      no       39     yes   no
# 4487   49  entrepreneur  divorced  secondary      no       32      no   no
# 4497   31  entrepreneur    single   tertiary      no       38      no   no
# 4520   44  entrepreneur    single   tertiary      no     1136     yes  yes
#
# ...

# %%
Entrepreneur = bank_record[bank_record['job'] == 'entrepreneur']
Entrepreneur.shape[0]
# Out:
# 168

# %%
bank_record[bank_record['job']=='entrepreneur']['y'].value_counts()
# Out:
# y
# no     153
# yes     15
# Name: count, dtype: int64

# %%
Subscribed_Entrepreneur = Entrepreneur['y'].value_counts(normalize=True)
Subscribed_Entrepreneur
# Out:
# y
# no     0.910714
# yes    0.089286
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6,8))
Subscribed_Entrepreneur.plot.pie(autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'], labels=['No', 'Yes'], startangle=90)
plt.title('Subscription Percentage Among Entrepreneurs')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=Entrepreneur, x='Loan Type')
plt.title('Loan Type Distribution among Entrepreneurs')
plt.xlabel('Loan Type')
plt.ylabel('Count')
plt.savefig('Plots/Loan_type_distribution_among_entrepreneurs.png')
plt.show()

# %%
print(Entrepreneur['Loan Type'].value_counts())
# Out:
# Loan Type
# Housing Loan Only     65
# No Loans              62
# Both Loans            29
# Personal Loan Only    12
# Name: count, dtype: int64

# %% [markdown]
# ### 💡 Insights
# - Entrepreneurs show a **very low subscription rate (~9%)**.
# - Majority hold **at least one loan**, reducing financial flexibility.
# - Only 37% of entrepreneurs have no loans — could indicate higher financial pressure.
#
# ---
#
# ### 🏁 Conclusion
# - Entrepreneurs are a **niche segment** with **low conversion potential** in current campaign strategy.
# - Financial product offerings may need to be **tailored** or **debt-sensitive** for better impact in this group.
#
# ---

# %% [markdown]
# ## 🧾 EDA on Clients with Negative Balance
#
# ### 📉 Total Clients with Negative Balance
# - **Total:** 366 clients
#
# ---
#
# ### 💼 Job Distribution (Negative Balance Group)
# - 🔵 Blue-collar: Highest count
# - 👔 Management: 2nd highest
# - 🖥️ Technician: 3rd
# - 🧑‍🍳 Services: 4th
# - 🗃️ Admin.: 5th
#
# > Majority of clients with negative balance come from blue-collar and management roles.
#
# ---
#
# ### 📊 Subscription Status (Negative Balance Group)
# - ❌ Not Subscribed: 91.5%
# - ✅ Subscribed: 8.5%
#
# ---

# %%
(bank_record['balance'] < 0).value_counts()
# Out:
# balance
# False    4155
# True      366
# Name: count, dtype: int64

# %%
negative_bal = bank_record[bank_record['balance'] < 0 ]

# %%
negative_bal
# Out:
#       age            job   marital  education default  balance housing loan  \
# 9      43       services   married    primary      no      -88     yes  yes
# 18     25    blue-collar    single    primary      no     -221     yes   no
# 48     32   entrepreneur    single    primary     yes     -849     yes  yes
# 60     41    blue-collar   married    primary      no     -516      no  yes
# 92     27       services    single  secondary      no     -195     yes   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4474   44    blue-collar   married    primary      no     -237     yes   no
# 4502   42       services   married  secondary      no      -91     yes  yes
# 4506   42     unemployed  divorced   tertiary      no     -166      no   no
# 4516   33       services   married  secondary      no     -333     yes   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=negative_bal, y='job', order=negative_bal['job'].value_counts().index, hue='job', palette='coolwarm')
plt.title("Bank Balance and Job Comparision")
plt.xlabel("Count")
plt.ylabel("Job")
plt.tight_layout()
plt.savefig('Plots/Bank_Balance_Job_Comparision.png')
plt.show()

# %%
sub_counts = negative_bal['y'].value_counts()

plt.figure(figsize=(12,5))
plt.pie(sub_counts, labels=sub_counts.index, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff'])
plt.title("Subscription Status among Negative Balance Customers")
plt.axis('equal')
plt.savefig('Plots/Subscription_Status_Negative_Balance.png')
plt.show()

# %% [markdown]
# ### 💡 Insights
# - Clients with **negative balance** show a **very low subscription rate** (only ~8.5%).
# - The group is **dominated by blue-collar and technician profiles**, potentially reflecting financial instability.
# - High proportion of non-subscribers implies a **clear risk-averse behavior** or **lack of eligibility**.
#
# ---
#
# ### 🏁 Conclusion
# - Individuals with negative balances are **high-risk, low-conversion** prospects.
# - Campaign strategies should either:
#   - Exclude this group from high-value offerings
#   - Or create **custom financial recovery products** before offering term deposits.
#
# ---

# %% [markdown]
# ## 🎓 EDA Summary: Education Level and Subscription Behavior
#
# ### 📊 Count of Customers by Education Level
# - 🏫 Secondary: 2,306 customers
# - 🎓 Tertiary: 1,350 customers
# - 📘 Primary: 678 customers
# - ❓ Unknown: 187 customers
#
# ---
#
# ### 📈 Subscription Rate (%) by Education Level
# - 🎓 Tertiary: **14.3%**
# - 🏫 Secondary: **10.6%**
# - ❓ Unknown: **10.2%**
# - 📘 Primary: **9.4%**
#
# ---
#
# ### 🔢 Total Customers by Education
# - Total distribution aligns with the counts listed above.
# - Reflects a broad spectrum of education backgrounds within the dataset.
#
# ---

# %%
bank_record['education'].value_counts().sort_values(ascending = False)
# Out:
# education
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: count, dtype: int64

# %%
primary_education = bank_record[bank_record['education'] == 'primary']

# %%
primary_education
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
secondary_education = bank_record[bank_record['education'] == 'secondary']

# %%
secondary_education
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y  \
# ...

# %%
tertiary_education = bank_record[bank_record['education'] == 'tertiary']

# %%
tertiary_education
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
# ...

# %%
unknown
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y  \
# ...

# %%
unknown = bank_record[bank_record['education'] == 'unknown']

# %%
subs_by_edu = bank_record.groupby('education')['y'].value_counts(normalize=True).unstack()['yes']*100
subs_by_edu.sort_values(ascending=False)
# Out:
# education
# tertiary     14.296296
# secondary    10.624458
# unknown      10.160428
# primary       9.439528
# Name: yes, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=subs_by_edu.index, y=subs_by_edu.values, hue=subs_by_edu.index, palette='viridis')
plt.title("Subscription Rate by Education")
plt.xlabel("Education levels")
plt.ylabel("Susbcription Rate (%)")
plt.tight_layout()
plt.savefig('Plots/Subscription_by_Education.png')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=bank_record, x='education', hue='education', order=bank_record['education'].value_counts().index, palette='pastel', legend=False)
plt.title("Total Customers by Education")
plt.xlabel("Education Type")
plt.ylabel("Count of people")
plt.tight_layout()
plt.savefig("Plots/Total_Customers_by_Education.png")
plt.show()

# %% [markdown]
# ### 🔑 Key Insights
# - 🏫 **Secondary education** forms the **largest group**, but with a **lower subscription rate** than tertiary.
# - 🎓 **Tertiary education** customers show the **highest subscription rate**, indicating **positive correlation between education and product adoption**.
# - ❓ Customers with **unknown education** still convert at a moderate rate, suggesting the potential value of this segment — and a need for **better data completeness**.
#
#
#
# ### 🏁 Conclusion
# - Education level plays a clear role in subscription behavior.
# - Marketing strategies should **prioritize tertiary-educated segments** for higher conversion.
# - Consider **data enrichment** for customers with unknown education to unlock further insights.
#
# ---

# %% [markdown]
# ## 💼 Subscription Rate by Job Profile
#
# | Job Profile    | Conversion Rate (%) |
# |----------------|---------------------|
# | 🗃️ Admin.       | 12.13%              |
# | 🔵 Blue-collar  | 7.29%               |
# | 📈 Entrepreneur | 8.93%               |
# | 🧹 Housemaid    | 12.50%              |
# | 👔 Management   | 13.52%              |
# | 👵 Retired      | 23.48%              |
# | 🧑‍🔧 Self-employed | 10.93%           |
# | 🧑‍🍳 Services   | 9.11%               |
# | 🎓 Student      | 22.62%              |
# | 🖥️ Technician   | 10.81%              |
# | 💼 Unemployed   | 10.16%              |
# | ❓ Unknown      | 18.42%              |
#
# ---

# %%
conversion_rate_df = converstion_rate.reset_index()
conversion_rate_df.columns=['job', 'conversion_rate']

# %%
converstion_rate = bank_record.groupby('job')['y'].value_counts(normalize=True).unstack()['yes']

# %%
conversion_rate_df
# Out:
#               job  conversion_rate
# 0          admin.         0.121339
# 1     blue-collar         0.072939
# 2    entrepreneur         0.089286
# 3       housemaid         0.125000
# 4      management         0.135191
# 5         retired         0.234783
# 6   self-employed         0.109290
# 7        services         0.091127
# 8         student         0.226190
# 9      technician         0.108073
# 10     unemployed         0.101562
# 11        unknown         0.184211

# %%
conversion_rate_df.sort_values(by='conversion_rate',ascending=False)
# Out:
#               job  conversion_rate
# 5         retired         0.234783
# 8         student         0.226190
# 11        unknown         0.184211
# 4      management         0.135191
# 3       housemaid         0.125000
# 0          admin.         0.121339
# 6   self-employed         0.109290
# 9      technician         0.108073
# 10     unemployed         0.101562
# 7        services         0.091127
# 2    entrepreneur         0.089286
# 1     blue-collar         0.072939

# %% [markdown]
# ### 💡 Insights
# - **Retired** and **students** show the highest subscription rates (23.5% and 22.6%), indicating strong engagement.
# - **Unknown** job profiles also convert at a relatively high rate (18.4%), suggesting these data points might represent a distinct group worth exploring.
# - **Blue-collar** and **entrepreneurs** have the lowest subscription rates, under 9%.
# - Management, admin, and housemaids fall in the moderate range (~12-13%).
#
#
#
# ### 🏁 Conclusion
# - Campaigns targeting **retired and student** segments may yield higher returns.
# - Efforts to better classify **unknown** job profiles could unlock additional insights.
# - Lower subscription rates among blue-collar and entrepreneurs signal potential need for tailored messaging or products.

# %% [markdown]
# # 🏠 Housing Loan Distribution by Job Category
#
# The table below shows the percentage of customers within each job group who have or do not have a housing loan. The values are normalized by job, representing the proportion of customers in each profession with respect to their housing loan status.
#
# | Job Category  | No Housing Loan (%) | Has Housing Loan (%) |
# | ------------- | ------------------- | -------------------- |
# | Admin         | 36.8%               | 63.2%                |
# | Blue-collar   | 26.5%               | 73.5%                |
# | Entrepreneur  | 44.0%               | 56.0%                |
# | Housemaid     | 65.2%               | 34.8%                |
# | Management    | 48.1%               | 51.9%                |
# | Retired       | 78.3%               | 21.7%                |
# | Self-employed | 51.9%               | 48.1%                |
# | Services      | 31.7%               | 68.3%                |
# | Student       | 76.2%               | 23.8%                |
# | Technician    | 44.8%               | 55.2%                |
# | Unemployed    | 54.7%               | 45.3%                |
# | Unknown       | 97.4%               | 2.6%                 |
#
#
# # 🔎 Insights:
# - The blue-collar (73.5%), services (68.3%), and admin (63.2%) groups have the highest proportions of customers with housing loans.
#
# - Retired (78.3%) and students (76.2%) predominantly do not have housing loans.
#
# - Entrepreneurs are fairly balanced, with slightly more than half (56%) holding housing loans.
#
# **The unknown category mostly lacks housing loans (97.4%), indicating potential missing data or unclassified entries.**

# %%
housing_loan = pd.crosstab(bank_record['job'], bank_record['housing'], normalize='index') * 100

# %%
housing_loan
# Out:
# housing               no        yes
# job
# admin.         36.820084  63.179916
# blue-collar    26.532770  73.467230
# entrepreneur   44.047619  55.952381
# housemaid      65.178571  34.821429
# management     48.090815  51.909185
# retired        78.260870  21.739130
# self-employed  51.912568  48.087432
# services       31.654676  68.345324
# student        76.190476  23.809524
# technician     44.791667  55.208333
# unemployed     54.687500  45.312500
# unknown        97.368421   2.631579

# %% [markdown]
# ### 💡 Insights
# - Blue-collar (73.5%) and services (68.3%) jobs have the **highest proportion of clients with housing loans**.
# - Retired (78.3%), students (76.2%), and unknown (97.4%) groups mostly **do not have housing loans**.
# - Management, self-employed, and technician groups are roughly evenly split.
# - Unknown group has very low housing loan holding, possibly due to incomplete data.
#
#
# ### 🏁 Conclusion
# - Housing loan uptake varies significantly by job role.
# - Targeting loan-related offers or risk assessments should consider these job-based housing loan trends.
# - Data quality improvement for “unknown” group needed for better profiling.

# %%
bank_record.to_csv("BankRecordFinal.csv", index=None)

# %% [markdown]
# ## 🏁 Final Conclusion
#
# This comprehensive exploratory data analysis on the bank marketing dataset uncovers critical insights that inform strategic decision-making:
#
# - **Customer Segmentation & Behavior:**
#   Education level, age group, and employment status strongly influence subscription rates. Notably, tertiary-educated customers, retirees, and students demonstrate the highest engagement with the bank’s term deposit products.
#
# - **Campaign & Contact Insights:**
#   The majority of contacts are concentrated in a few campaigns, with cellular communication driving the most leads. Campaign timing significantly impacts conversion, with October, December, and March showing peak subscription rates.
#
# - **Financial Profile Impact:**
#   Loan status is a key determinant of subscription behavior; customers without loans exhibit higher subscription rates, while those with multiple loans or negative balances show lower engagement, suggesting increased financial risk.
#
# - **Data Quality & Opportunities:**
#   Segments marked as ‘unknown’ in job and education categories represent an area for data enrichment, as they surprisingly show moderate to high subscription rates.
#
# ### Strategic Implications
#
# - Prioritize marketing efforts toward high-conversion segments (tertiary-educated, retirees, students) to maximize ROI.
# - Customize product offerings and communication for lower-performing groups such as entrepreneurs and blue-collar workers.
# - Leverage campaign timing insights to optimize outreach scheduling.
# - Invest in data quality improvement to unlock hidden opportunities within ‘unknown’ segments.
# - Develop risk-sensitive strategies for financially vulnerable clients to enhance long-term customer value.
#
# This analysis demonstrates strong proficiency in data-driven marketing strategy and customer segmentation. The actionable insights can directly contribute to improving campaign effectiveness and business outcomes.
#
# ---
#
# *This project showcases skills in data exploration, visualization, and business insight generation — key strengths for any data analyst or data scientist portfolio.*
